# %% [markdown]
# 1	Milk, Bread, Butter
# 2	Milk, Bread
# 3	Bread, Butter, Eggs
# 4	Milk, Butter
# 5	Bread, Eggs
# 6	Milk, Bread, Butter, Eggs
# 7	Bread, Butter
# 8	Milk, Eggs
# 9	Milk, Bread
# 10	Bread, Butter, Eggs
#
# Thresholds:
# •    Minimum Support: 40%.
# •    Focus on frequent 1-itemsets, 2-itemsets, and 3-itemsets.

# %% [markdown]
# #### Part 1: Apriori Algorithm (10 Marks)
# 1. Find frequent 1-itemsets:
#
# $ \because min\_support = 40\%$
# There are 10 transactions.
# $$ \therefore min\_support = \frac{40}{100} * 10 = 4$$
#
# 1-itemsets
# Milk: 6
# Bread: 8
# Butter: 6
# Eggs: 5
#
# Frequent 1-itemsets (occurrences ≥ 4):
# Milk, Bread, Butter, Eggs
#
# 2-itemsets
# {Milk, Bread} = 4
# {Milk, Butter} = 3
# {Milk, Eggs} = 2
# {Bread, Butter} = 5
# {Bread, Eggs} = 4
# {Butter, Eggs} = 3
#
# Frequent 2-itemsets (occurrences ≥ 4):
#
# {Bread, Eggs}, {Milk, Bread}, {Bread, Butter},
#
# 3-itemsets
# {Milk, Bread, Butter} = 2
# {Milk, Bread, Eggs} = 1
# {Bread, Butter, Eggs} = 3
# {Milk, Butter, Eggs} = 1
#
# Frequent 3-itemsets (occurrences ≥ 4):
# None of these 3-itemsets meet the minimum support threshold of 4.
#
#
# ### Final Frequent itemsets:
#
# 1-itemset:
# {Milk}: 6
# {Bread}: 8
# {Butter}: 6
# {Eggs}: 5
#
# 2-itemsets:
# {Bread, Butter}: 5
# {Bread, Eggs} = 4
# {Milk, Bread} = 4

# %% [markdown]
# #### Part 2: FP-Growth Algorithm
#
# Mining Eggs:
# {Bread, Milk, Butter} = 1
# {Bread} = 1
# {Bread, Butter} = 2
# {Milk} = 1
#
# **Frequent itemsets from Eggs:**
# {Eggs} = 5
# {Bread, Eggs} = 4
# {Butter, Eggs} = 3(not frequent)
#
# Mining Butter:
# {Bread, Milk} = 2
# {Bread} = 3
# {Milk} = 1
#
# **Frequent itemsets from Butter:**
# {Butter} = 6
# {Bread, Butter} = 5
# {Milk, Butter} = 3(not frequent)
#
# Mining Milk:
# {Bread} support = 4
#
# **Frequent itemsets from Milk:**
# {Milk} = 6
# {Bread, Milk} = 4
#
# Bread:
# Bread is already frequent on its own.
# {Bread} = 8
#
# ### Final Frequent Itemsets:
#
# 1-itemsets:
# {Bread}: 8, {Milk}: 6, {Butter}: 6, {Eggs}: 5,
# 2-itemsets:
# {Bread, Eggs}: 4, {Bread, Butter}: 5, {Bread, Milk}: 4,

# %% [markdown]
# ### Conclusion
#
# Both methods yield the same frequent itemsets, confirming their consistency in mining patterns from the dataset.
#
# The Apriori algorithm is straightforward but inefficient for large datasets due to its multiple passes and exponential itemset growth, while FP-Growth, though initially complex with tree construction, is more efficient and scalable for dense or large datasets.
